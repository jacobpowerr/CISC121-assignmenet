# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1 Fizz Buzz

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# ![Screenshot 2025-09-20 153801.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Peer Review & Draft Code

# %%
# Your draft code here (does not need to be fully correct)
class Solution(object):
    def fizzBuzz(self, n):
      for i in range(1, n + 1):
        if i % 3 == 0 and i % 5 == 0:
          return "FizzBuzz"
        elif i % 3 == 0:
          return "Fizz"
        elif i % 5 == 0:
          return "Buzz"
        else:
          return str(i)

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final working solution
# Used Chatgpt to hint to me why my code was not passing test
# Example prompt: give me some hints as to why my code is failing

class Solution(object):
  def fizzbuzz(self, n):
    result = []

    for i in range(1, n + 1):
      if i % 3 == 0 and i % 5 == 0:
        result.append("FizzBuzz")
      elif i % 3 == 0:
        result.append("Fizz")
      elif i % 5 == 0:
        result.append("Buzz")
      else:
        result.append(str(i))

      return result

# %% [markdown]
# ![Screenshot 2025-09-20 213107.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# Fix Number 1:
# Adding an empty list at the begining:
result = []
# Allowed me to add all the desired outputs.

# %%
# Fix Number 2:
# Draft version ():
          return "FizzBuzz"
        elif i % 3 == 0:
          return "Fizz"
        elif i % 5 == 0:
          return "Buzz"
  # Fixed version (allows me to output more than one that at once):
          result.append("FizzBuzz")
      elif i % 3 == 0:
        result.append("Fizz")
      elif i % 5 == 0:
        result.append("Buzz")
      else:
        result.append(str(i))
# Out:
#   File "<tokenize>", line 4
#     elif i % 3 == 0:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
#
# 1. Chatgpt helped me identify that I needed to use a list instead of just simply attempting to return outputs within the loop.
#
# 2. Once Chatgpt told me I had to use a list I was able to see that instead of returning the outputs, I simply needed to add the desired outputs to the list and then return the list.

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# 1. Your Name: Jacob Power
# 2. Section: 4
# 3. ID: 20545956
# 4. Github Link of this notebook (the link of Github Repo where you saved your notebook)
# 5. Chat (Saved Chat  with your AI tool in a shared Document link)[Optional]

# %% [markdown]
# # Problem 2 Palindrome Number

# %% [markdown]
# # 1. Understanding and Breakdown
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Peer Review and Draft Code

# %%
class Solution(object):
    def isPalindrome(self, x):
        x = str(x)
        reverse_number = []
        for i in range(len(x)-1, -1, -1):
            reverse_number.append(i)
        return reverse_number == x

# %% [markdown]
# # 3. Final Correct Code

# %%
# Used Chatgpt to hint to me why my code was not passing test
# Example prompt: give me some hints as to why my code is failing
class Solution(object):
    def isPalindrome(self, x):
        s = str(x)
        return s == s[::-1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Reviews and Fixes

# %%
# Got rid of the list and did not use a loop method.
# Draft version:
reverse_number = []
for i in range(len(x)-1, -1, -1):

# %%
# Used a slicing method.
# Fixed version:
return s == s[::-1]

# %% [markdown]
# # 5. Reflection on Your Contribution
#
# 1. I ran my original code through chatpgt and asked what was wrong with it. It told me to not be using a list method but instead a slicing method.
#
# 2. Once it told me to just simply think in terms of slicing I realised that I just needed to use a slicing method that started at the end and then went backwards over each character. Was very similar to original code, just used a different method.

# %% [markdown]
# # Problem 3 Reverse Integer

# %% [markdown]
# # 1. Understanding and Breakdown
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Peer Review and Draft Code

# %%
class Solution(object):
    def reverse(self, x):
       s = str(x)
        return int(s[::-1])

# %% [markdown]
# # 3. Final Correct Code

# %%
# Used Chatgpt to hint to me why my code was not passing test
# Example prompt: give me some hints as to why my code is failing
class Solution(object):
    def reverse(self, x):
        s = str(x)
        if s[0] == "-":
            result = -int(s[:0:-1])
        else:
            result = int(s[::-1])

        if result < -2**31 or result > 2**31 -1:
            return 0
        return result

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Review and Fixes

# %%
# Mainly just added new code. All of my previous code was still in the final code

# %%
# Added if statement to handle for the - sign:
if s[0] == "-":
    result = -int(s[:0:-1])

# %%
# Added another if statement to handle the edge case of the number being too small or too large:
if result < -2**31 or result > 2**31 -1:
            return 0
        return result

# %% [markdown]
# # 5. Reflection on Your Contribution
#
# 1. After my submission and tests failed I ran my code through Chatgpt and it reminded me to make sure to handle for edge cases.
#
# 2. It reminded me to handle for the negative sign, where I then realised that I had to use a conditional and different method of slicing if the negative sign was present.
#
# 3. It also reminded me to handle for the size of the number. Where I then remebered that the question was asking for me to ensure that the number was neither too small nor too big and so I added another conditional to ensure the number was within the correct range.

# %% [markdown]
# # Problem 3 Two Sum

# %% [markdown]
# # 1. Understanding and Breakdown

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Peer Review and Draft Code

# %%
class Solution(object):
    def twoSum(self, nums, target):
        hashmap = {}
        for i in range(len(nums)):
            if target - nums[i] == hashmap[i]:
                return [i, hashmap[i]]
            else:
                hashmap[i] = nums[i]

# %% [markdown]
# # 3. Final Correct Code

# %%
# Used Chatgpt to hint to me why my code was not passing test
# Example prompt: give me some hints as to why my code is failing
class Solution(object):
    def twoSum(self, nums, target):
        hashmap = {}
        for i in range(len(nums)):
            complement = target - nums[i]
            if complement in hashmap:
                return [i, hashmap[complement]]
            hashmap[nums[i]] = i

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Review and Fixes

# %%
# Fix number 1:
complement = target - nums[i]
# In my original code I was creating a variable complement
# Without this variable I could not check to see wether the complement was in the hashmap
if complement in hashmap:

# %%
# Fix number 2:
# Original:
    return [i, hashmap[i]]
else:
    hashmap[i] = nums[i]
# Fixed:
  return [i, hashmap[complement]]
hashmap[nums[i]] = i
# I was mixing up the indexes with the numbers
# Instead of storing the index as the value and the number as the key, I was doing the oppostite

# %% [markdown]
# # 5. Reflection on Your Contribution
#
# 1. Chatgpt told me to create a variable that was the complement number. After this I was able to realise that I needed to check to see wether the complement was stored in the hashmap.
# 2. Chatgpt also told me that I was mixing up my keys and values. Storing indexes where the numbers were supposed to be.

# %% [markdown]
# # Problem 5 Valid Palindrome

# %% [markdown]
# # 1. Understanding and Breakdown

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Peer Review and Draft Code

# %%
class Solution(object):
    def isPalindrome(self, s):
        s == s.strip().lower()
        return s == s[::-1]

# %% [markdown]
# # 3. Final Correct Code

# %%
# Used Chatgpt to hint to me why my code was not passing test
# Example prompt: give me some hints as to why my code is failing
class Solution(object):
    def isPalindrome(self, s):
        cleaned = "".join(ch.lower() for ch in s if ch.isalnum())
        return cleaned == cleaned[::-1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Review and Fixes

# %%
# Fix number 1:
"".join
# Created an empty list and joined cleaned charcters to it

# %%
# Fix number 2:
(ch.lower() for ch in s if ch.isalnum())
# Looped through each char and ensured it was a letter or number, if it is it gets added
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3335163520.py in <cell line: 0>()
#       1 # Fix number 2:
# ----> 2 (ch.lower() for ch in s if ch.isalnum())
#
# NameError: name 's' is not defined

# %% [markdown]
# # 5. Reflection on Your Contribution.
#
# 1. Chatgpt recommended that I first create a empty string. I then realised I needed to clean each char and then store it.
#
# 2. Chatgpt told me that I needed to check to make sure that each char was either a letter or a number. If it wasn't, than it should not be in the cleaned version.

# %% [markdown]
# 1. Your Name: Jacob Power
# 2. Section: 4
# 3. ID: 20545956
# 4. Github Link of this notebook: https://github.com/jacobpowerr/CISC121-assignmenet/blob/main/Copy_of_Assignement_1%20(1).ipynb
